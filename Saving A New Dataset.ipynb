# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Data Description

# %%
wga_csv = pd.read_csv("Result_WGA.csv")

# %%
wga_csv.columns
# Out:
# Index(['Client', 'GroupCode', 'NominatedBankAccountNumber', 'TransactionType',
#        'TransactionDescription', 'DocumentType', 'DocumentDescription',
#        'TransactionDocumentNumber', 'Payee', 'RequisitionNumber',
#        'ChequeNumber', 'UserReference1', 'UserReference2', 'Code2Reference',
#        'TransactionAmount', 'TransactionActionDate', 'TransactionMovementDate',
#        'TransactionStatus', 'HomingAccountNumber', 'HomingBankName',
#        'HomingBankBranch', 'HomingBankBranchName', 'HomingBankAccountType',
#        'TransactionCreatedDate', 'TransactionCreatedTime', 'UnpaidErrorCode',
#        'UnpaidErrorDescription', 'UnpaidEffectiveDate', 'UnpaidMovementDate',
#        'UnpaidAgeInDays', 'IncomingBatchNumber', 'UniqueUserCode',
#        'EFTBatchNumber', 'TransactionDateRequested',
#        'TransactionTimeRequested', 'TransmissionService', 'DebiCheckStatus',
#        'DebiCheckTrackingPeriod', 'DebiCheckCollectionDate',
# ...

# %%
wga_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545475 entries, 0 to 545474
# Data columns (total 41 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Client                      545475 non-null  object
#  1   GroupCode                   545475 non-null  object
#  2   NominatedBankAccountNumber  545475 non-null  int64
#  3   TransactionType             545475 non-null  object
#  4   TransactionDescription      545475 non-null  object
#  5   DocumentType                545475 non-null  int64
#  6   DocumentDescription         545475 non-null  object
#  7   TransactionDocumentNumber   545475 non-null  int64
#  8   Payee                       545475 non-null  object
#  9   RequisitionNumber           545475 non-null  int64
#  10  ChequeNumber                545475 non-null  object
#  11  UserReference1              545475 non-null  object
#  12  UserReference2              545475 non-null  object
# ...

# %% [markdown]
# Get a gist of the data to understand what the columns do

# %% [markdown]
# ### Exploratory Data Analysis

# %%
wga_csv.head()
# Out:
#       Client                       GroupCode  NominatedBankAccountNumber  \
# 0  FACWGAPDB  EFT COLLECTIONS - UNPAID                        4077846457
# 1  FACWGAPDB  EFT COLLECTIONS - UNPAID                        4077846457
# 2  FACWGAPDB  EFT COLLECTIONS - UNPAID                        4077846457
# 3  FACWGAPDB  EFT COLLECTIONS - UNPAID                        4077846457
# 4  FACWGAPDB  EFT COLLECTIONS - UNPAID                        4077846457
#
#   TransactionType          TransactionDescription  DocumentType  \
# 0           FDC10  DEBICHECK FNB                              7
# 1           FDC10  DEBICHECK FNB                              7
# 2           FDC10  DEBICHECK FNB                              7
# 3           FDC10  DEBICHECK FNB                              7
# 4           FDC10  DEBICHECK FNB                              7
#
#               DocumentDescription  TransactionDocumentNumber  \
# 0  NAEDO 07 DAY                                          100
# ...

# %%
wga_csv['Payee'].value_counts()
# Out:
# Payee
# T Ronne                                           0010202312247869C91F4F    RCUR    7
# MD Ridley                                         001020240106F8AA25290D    RCUR    7
# T Khumalo                                         0010202311293354E49093    RCUR    7
# L Nhlapo                                          0010202312090A3B9AD9F4    RCUR    7
# Y Dookoo                                          001020231128633F919ECC    RCUR    7
#                                                                                    ..
# d coetzee                                         0003202403140623725205    RCUR    1
# J RULE                                            0002202402200000001872    RCUR    1
# e didisha                                         0016202402289313317715    RCUR    1
# Z Makolo                                          0002202403010000003571    RCUR    1
# S Bvuma                                           00102024080291BC8D51C9    RCUR    1
# ...

# %%
for i in wga_csv.columns:
    print(f"Unique {i}'s count: {wga_csv[i].nunique()}")
    print(f"{wga_csv[i].unique()}\n")
# Out:
# Unique Client's count: 1
# ['FACWGAPDB']
#
# Unique GroupCode's count: 1
# ['EFT COLLECTIONS - UNPAID      ']
#
# Unique NominatedBankAccountNumber's count: 1
# [4077846457]
#
# Unique TransactionType's count: 1
# ['FDC10']
#
# Unique TransactionDescription's count: 1
# ['DEBICHECK FNB                 ']
#
# Unique DocumentType's count: 1
# [7]
#
# Unique DocumentDescription's count: 1
# ['NAEDO 07 DAY                  ']
#
# Unique TransactionDocumentNumber's count: 1
# [100]
#
# Unique Payee's count: 283520
# ['M Mothibe                                         0001202305020000014793    RCUR'
#  'S Mngoma                                          0002202212100000004303    RCUR'
#  'N Maliga                                          0001202304030000010002    RCUR'
#  ...
#  'TR Matlejoane                                     00102024080274559C3F03    RCUR'
#  'K Ranamane                                        00102024080142242F1597    RCUR'
# ...

# %%
value_counts = wga_csv['Payee'].value_counts()
filtered_values = value_counts[value_counts > 5].index
filtered_values
# Out:
# Index(['T Ronne                                           0010202312247869C91F4F    RCUR',
#        'MD Ridley                                         001020240106F8AA25290D    RCUR',
#        'T Khumalo                                         0010202311293354E49093    RCUR',
#        'L Nhlapo                                          0010202312090A3B9AD9F4    RCUR',
#        'Y Dookoo                                          001020231128633F919ECC    RCUR',
#        'b bele                                            001020240103B63516CE14    RCUR',
#        'C Louw                                            0001202312220000016189    RCUR',
#        'L Van AS                                          0001202401080000015156    RCUR',
#        'A Solomons                                        0002202401010000000351    RCUR',
#        'Rv van der Hoff                                   0016202401111512776854    RCUR',
#        ...
# ...

# %%
filtered_df = wga_csv[wga_csv['Payee'].isin(filtered_values)]
filtered_df
# Out:
#            Client                       GroupCode  NominatedBankAccountNumber  \
# 50      FACWGAPDB  EFT COLLECTIONS - UNPAID                        4077846457
# 138     FACWGAPDB  EFT COLLECTIONS - UNPAID                        4077846457
# 305     FACWGAPDB  EFT COLLECTIONS - UNPAID                        4077846457
# 511     FACWGAPDB  EFT COLLECTIONS - UNPAID                        4077846457
# 512     FACWGAPDB  EFT COLLECTIONS - UNPAID                        4077846457
# ...           ...                             ...                         ...
# 544608  FACWGAPDB  EFT COLLECTIONS - UNPAID                        4077846457
# 544835  FACWGAPDB  EFT COLLECTIONS - UNPAID                        4077846457
# 545123  FACWGAPDB  EFT COLLECTIONS - UNPAID                        4077846457
# 545202  FACWGAPDB  EFT COLLECTIONS - UNPAID                        4077846457
# 545464  FACWGAPDB  EFT COLLECTIONS - UNPAID                        4077846457
#
# ...

# %%
filtered_df.to_csv("Mini_Result_WGA.csv", index=False)
